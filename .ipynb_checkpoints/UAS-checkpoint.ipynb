# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("laptop_price.csv", encoding="latin1")

avg_price_company = df.groupby("Company")["Price_euros"].mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=avg_price_company.index, y=avg_price_company.values, palette="viridis")
plt.xticks(rotation=45)
plt.ylabel("Rata-Rata harga(Euros)")
plt.title("Rata-Rata harga berdasarkan perusahaan")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ibnuh\AppData\Local\Temp\ipykernel_1528\4294901272.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_company.index, y=avg_price_company.values, palette="viridis")

# %%
mean_price = df["Price_euros"].mean()
median_price = df["Price_euros"].median()
mode_price = df["Price_euros"].mode()[0] 

# Print results
print(f"Mean(euro): {mean_price:.2f}")
print(f"Median(euro): {median_price:.2f}")
print(f"Modus(euro): {mode_price:.2f}")
# Out:
# Mean(euro): 1123.69
# Median(euro): 977.00
# Modus(euro): 1099.00

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["Price_euros"], bins=30, kde=True, color="red")
plt.xticks(rotation=45)
plt.xlabel("Price (Euros)")
plt.ylabel("Count")
plt.title("distribusi harga laptop")
plt.tight_layout()
plt.show()
